# %% [markdown]
# # Lab 2

# %% [markdown]
# # View the Data

# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd
df = pd.read_csv('s3://ia340466879/NTAD_Aviation_Facilities_7163558772200366310.csv') # load the data from s3
df.head() #show the top 5 rows
# Out:
#    OBJECTID    EFF_DATE  SITE_NO SITE_TYPE_CODE STATE_CODE ARPT_ID       CITY  \
# 0         1  2025/08/07   103.00              A         AL     0J0  ABBEVILLE
# 1         2  2025/08/07   106.00              A         AL     2A8    ADDISON
# 2         3  2025/08/07   108.00              A         AL    AL03      AKRON
# 3         4  2025/08/07   110.00              A         AL     EET  ALABASTER
# 4         5  2025/08/07   110.01              H         AL    AL39  ALABASTER
#
#   COUNTRY_CODE REGION_CODE ADO_CODE  ... TRNS_STRG_HGR_FLAG  \
# 0           US         ASO      JAN  ...                NaN
# 1           US         ASO      JAN  ...                NaN
# 2           US         ASO      JAN  ...                NaN
# 3           US         ASO      JAN  ...                NaN
# 4           US         ASO      JAN  ...                NaN
#
#   TRNS_STRG_TIE_FLAG    OTHER_SERVICES WIND_INDCR_FLAG ICAO_ID MIN_OP_NETWORK  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19901 entries, 0 to 19900
# Data columns (total 93 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   OBJECTID                  19901 non-null  int64
#  1   EFF_DATE                  19901 non-null  object
#  2   SITE_NO                   19901 non-null  float64
#  3   SITE_TYPE_CODE            19901 non-null  object
#  4   STATE_CODE                19754 non-null  object
#  5   ARPT_ID                   19901 non-null  object
#  6   CITY                      19901 non-null  object
#  7   COUNTRY_CODE              19901 non-null  object
#  8   REGION_CODE               19754 non-null  object
#  9   ADO_CODE                  16107 non-null  object
#  10  STATE_NAME                19754 non-null  object
#  11  COUNTY_NAME               19901 non-null  object
#  12  COUNTY_ASSOC_STATE        19901 non-null  object
# ...

# %%
df.describe()
# Out:
#            OBJECTID       SITE_NO       LAT_DEG       LAT_MIN       LAT_SEC  \
# count  19901.000000  19901.000000  19901.000000  19901.000000  19901.000000
# mean    9951.000000  15629.636951     38.478921     29.666851     29.564715
# std     5745.068189  12918.008107      7.313601     17.187896     17.586454
# min        1.000000    103.000000      5.000000      0.000000      0.000000
# 25%     4976.000000   5251.500000     34.000000     15.000000     14.356000
# 50%     9951.000000  13319.000000     39.000000     30.000000     29.963000
# 75%    14926.000000  23373.220000     42.000000     44.000000     44.891200
# max    19901.000000  90970.000000     76.000000     59.000000     59.999000
#
#         LAT_DECIMAL      LONG_DEG      LONG_MIN      LONG_SEC  LONG_DECIMAL  \
# count  19901.000000  19901.000000  19901.000000  19901.000000  19901.000000
# mean      38.975750     94.894528     29.155922     29.721235    -94.770667
# ...

# %%
df.shape #number of rows and columns
# Out:
# (19901, 93)

# %% [markdown]
# My data consists of 19,901 rows and 93 columns. This is a large dataset meaning I will most likely have to clean my data sheet to find information I look for. My first impression of this data set is that it contains a lot of information but most of this information will most likely not be useful to me.

# %% [markdown]
# # Clean Data

# %%
df = df.rename(columns={"SITE_TYPE_CODE"	: "site code"})
df.head()
# Out:
#    OBJECTID    EFF_DATE  SITE_NO site code STATE_CODE ARPT_ID       CITY  \
# 0         1  2025/08/07   103.00         A         AL     0J0  ABBEVILLE
# 1         2  2025/08/07   106.00         A         AL     2A8    ADDISON
# 2         3  2025/08/07   108.00         A         AL    AL03      AKRON
# 3         4  2025/08/07   110.00         A         AL     EET  ALABASTER
# 4         5  2025/08/07   110.01         H         AL    AL39  ALABASTER
#
#   COUNTRY_CODE REGION_CODE ADO_CODE  ... TRNS_STRG_HGR_FLAG  \
# 0           US         ASO      JAN  ...                NaN
# 1           US         ASO      JAN  ...                NaN
# 2           US         ASO      JAN  ...                NaN
# 3           US         ASO      JAN  ...                NaN
# 4           US         ASO      JAN  ...                NaN
#
#   TRNS_STRG_TIE_FLAG    OTHER_SERVICES WIND_INDCR_FLAG ICAO_ID MIN_OP_NETWORK  \
# 0                  Y               NaN             Y-L     NaN              N
# ...

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of        OBJECTID  EFF_DATE  SITE_NO  site code  STATE_CODE  ARPT_ID   CITY  \
# 0         False     False    False      False       False    False  False
# 1         False     False    False      False       False    False  False
# 2         False     False    False      False       False    False  False
# 3         False     False    False      False       False    False  False
# 4         False     False    False      False       False    False  False
# ...         ...       ...      ...        ...         ...      ...    ...
# 19896     False     False    False      False        True    False  False
# 19897     False     False    False      False        True    False  False
# 19898     False     False    False      False        True    False  False
# 19899     False     False    False      False        True    False  False
# 19900     False     False    False      False        True    False  False
#
# ...

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# OBJECTID          0
# EFF_DATE          0
# SITE_NO           0
# SITE_TYPE_CODE    0
# STATE_CODE        0
#                  ..
# MIN_OP_NETWORK    0
# USER_FEE_FLAG     0
# CTA               0
# x                 0
# y                 0
# Length: 93, dtype: int64

# %%
df.columns
# Out:
# Index(['OBJECTID', 'EFF_DATE', 'SITE_NO', 'SITE_TYPE_CODE', 'STATE_CODE',
#        'ARPT_ID', 'CITY', 'COUNTRY_CODE', 'REGION_CODE', 'ADO_CODE',
#        'STATE_NAME', 'COUNTY_NAME', 'COUNTY_ASSOC_STATE', 'ARPT_NAME',
#        'OWNERSHIP_TYPE_CODE', 'FACILITY_USE_CODE', 'LAT_DEG', 'LAT_MIN',
#        'LAT_SEC', 'LAT_HEMIS', 'LAT_DECIMAL', 'LONG_DEG', 'LONG_MIN',
#        'LONG_SEC', 'LONG_HEMIS', 'LONG_DECIMAL', 'SURVEY_METHOD_CODE', 'ELEV',
#        'ELEV_METHOD_CODE', 'MAG_VARN', 'MAG_HEMIS', 'MAG_VARN_YEAR', 'TPA',
#        'CHART_NAME', 'DIST_CITY_TO_AIRPORT', 'DIRECTION_CODE', 'ACREAGE',
#        'RESP_ARTCC_ID', 'COMPUTER_ID', 'ARTCC_NAME', 'FSS_ON_ARPT_FLAG',
#        'FSS_ID', 'FSS_NAME', 'PHONE_NO', 'TOLL_FREE_NO', 'ALT_FSS_ID',
#        'ALT_FSS_NAME', 'ALT_TOLL_FREE_NO', 'NOTAM_ID', 'NOTAM_FLAG',
#        'ACTIVATION_DATE', 'ARPT_STATUS', 'FAR_139_TYPE_CODE',
#        'FAR_139_CARRIER_SER_CODE', 'ARFF_CERT_TYPE_DATE', 'NASP_CODE',
# ...

# %% [markdown]
# I renamed SITE_TYPE_CODE to simply site code as it is easier to type out in future code.
# I have 11 instances of missing values and I handled them by droping them from my datasheet

# %% [markdown]
# # C Manipulate Data

# %%
city_df= df[['CITY']]

# %%
df.sort_values (by='SITE_TYPE_CODE')
# Out:
#        OBJECTID    EFF_DATE   SITE_NO SITE_TYPE_CODE STATE_CODE ARPT_ID  \
# 0             1  2025/08/07    103.00              A         AL     0J0
# 12148     12149  2025/08/07  18154.20              A         OH    32OH
# 12149     12150  2025/08/07  18157.00              A         OH     MFD
# 12151     12152  2025/08/07  18158.01              A         OH    OH97
# 12154     12155  2025/08/07  18166.00              A         OH    75OI
# ...         ...         ...       ...            ...        ...     ...
# 4403       4404  2025/08/07   4625.80              U         IL    II31
# 4401       4402  2025/08/07   4625.21              U         IL     3H5
# 5220       5221  2025/08/07   5540.81              U         IN    36IN
# 11495     11496  2025/08/07  17208.10              U         NC    85NC
# 13930     13931  2025/08/07  21553.91              U         PA    5PA9
#
#                 CITY COUNTRY_CODE REGION_CODE ADO_CODE  ...  \
# ...

# %%
df[5:10]
# Out:
#              CITY
# 5     ALBERTVILLE
# 6  ALEXANDER CITY
# 7  ALEXANDER CITY
# 8      ALICEVILLE
# 9       ANDALUSIA

# %%
df[df['STATE_CODE']=='IL']
# Out:
#       OBJECTID    EFF_DATE   SITE_NO SITE_TYPE_CODE STATE_CODE ARPT_ID  \
# 4211      4212  2025/08/07  4363.000              A         IL    IL01
# 4212      4213  2025/08/07  4366.000              A         IL     C00
# 4213      4214  2025/08/07  4366.010              H         IL    12IS
# 4214      4215  2025/08/07  4368.800              A         IL    7IS7
# 4215      4216  2025/08/07  4369.000              A         IL    0IL2
# ...        ...         ...       ...            ...        ...     ...
# 4847      4848  2025/08/07  5071.210              H         IL    IL42
# 4848      4849  2025/08/07  5073.015              H         IL    3IL5
# 4849      4850  2025/08/07  5074.000              A         IL     2C6
# 4850      4851  2025/08/07  5074.500              H         IL    62LL
# 4851      4852  2025/08/07  5075.000              A         IL    IL02
#
#             CITY COUNTRY_CODE REGION_CODE ADO_CODE  ... TRNS_STRG_HGR_FLAG  \
# ...

# %% [markdown]
# The columsn that I relected was the City column and I sorted it by the site type code, and then I filtered the State Code by IL or Illinious

# %% [markdown]
# # Group and Visualize Data

# %%
WIND_INDCR_FLAG=df.groupby('REGION_CODE')['CITY'].count() 
WIND_INDCR_FLAG.head()
# Out:
# REGION_CODE
# AAL     775
# ACE    1435
# AEA    2291
# AGL    3741
# ANE     850
# Name: CITY, dtype: int64

# %% [markdown]
# this groupby function counts how many times a city appears in a region code. In this instance these number can be used to find how many airports/airfields there are in Alabama.

# %%
WIND_INDCR_FLAG.plot()
# Out:
# <Axes: xlabel='REGION_CODE'>

# %% [markdown]
# This Graph shows which City by region code in Alabama has the most airports/airfilds. Form the visualization I can see that soem cities habe a much higher amount of airfilds than other.

# %%
WIND_INDCR_FLAG.nlargest(10).plot.bar()
# Out:
# <Axes: xlabel='REGION_CODE'>

# %% [markdown]
# This plot takes the same data as the one above but showis it in an easier to read format. From this we can see that AGL,AWS, and ASO are the Cities with the higherst number of Airfilds.

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 Airport_Data=df[df['STATE_CODE']=='AL']
# ----> 2 Airport_Data.reset_index().plot.scatter(x='LAST_INSPECTION',y='CITY',c='WIND_INDCR_FLAG')
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/plotting/_core.py:1748, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1660 def scatter(
#    1661     self,
#    1662     x: Hashable,
#    (...)
#    1666     **kwargs,
#    1667 ) -> PlotAccessor:
#    1668     """
#    1669     Create a scatter plot with varying marker point size and color.
#    1670
#    (...)
#    1746         ...                       colormap='viridis')
#    1747     """
# -> 1748     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.hist(layout=(2,2), figuresize=(10,5), sharey=False, Sharex=False, bins=50)
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/plotting/_core.py:251, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     164 """
#     165 Make a histogram of the DataFrame's columns.
#     166
#    (...)
#     248     >>> hist = df.hist(bins=3)
#     249 """
#     250 plot_backend = _get_plot_backend(backend)
# --> 251 return plot_backend.hist_frame(
#     252     data,
#     253     column=column,
#     254     by=by,
#     255     grid=grid,
#     256     xlabelsize=xlabelsize,
#     257     xrot=xrot,
#     258     ylabelsize=ylabelsize,
#     259     yrot=yrot,
#     260     ax=ax,
# ...
